# %% [markdown]
# # Cuaderno especial:
# ## Enlazando Gurobi con Anaconda
#
# Luego de haber instalado Gurobi y activado la licencia (ver instrucciones [aquí](https://epnecuador-my.sharepoint.com/:b:/g/personal/luis_torres_epn_edu_ec/EdNw56R9xaxKi22QKkL83-QB_QoT5mxaKBQtFYLlA8bW3A?e=ae2gEm)), debe ejecutarse la siguiente celda de código **por una sola vez** para enlazar Gurobi con Anaconda y permitir el acceso al API Python de Gurobi desde los cuadernos de Jupyter.

# %%
import sys
# !conda config --add channels http://conda.anaconda.org/gurobi
# !conda install --yes --prefix {sys.prefix} gurobi
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/luismiguel/anaconda3
#
#   added / updated specs:
#     - gurobi
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python-3.8.12              |       h12debd9_0        22.2 MB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     certifi-2021.10.8          |   py38h06a4308_2         156 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     zlib-1.2.11                |       h7f8727e_4         125 KB
#     ncurses-6.3                |       h7f8727e_2         1.0 MB
#     tk-8.6.11                  |       h1ccaba5_0         3.2 MB
# ...
